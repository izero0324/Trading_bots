# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

import pkg_resources
import types
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-job3v4fd because the default path (/home/ubuntu/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/ubuntu/tensorflow/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
import finlab_crypto
finlab_crypto.setup()
df = finlab_crypto.crawler.get_all_binance('FTTUSDT', '1h')
#df = pd.read_csv('./history/BTCUSDT-1h-data.csv')
df.describe()
# Out:
# Downloading 23940 minutes of new data available for FTTUSDT, i.e. 399 instances of 1h data.
# All caught up..!
#                open          high           low         close         volume  \
# count  11262.000000  11262.000000  11262.000000  11262.000000   11262.000000
# mean       7.028215      7.078226      6.976026      7.030964   15234.567604
# std        9.539740      9.619108      9.458703      9.544288   31716.313416
# min        1.940000      1.984000      0.500000      1.955000       0.000000
# 25%        2.728000      2.739250      2.717000      2.729000    1789.823000
# 50%        3.403000      3.418000      3.386000      3.403000    5948.756000
# 75%        4.455500      4.469750      4.430000      4.453500   15748.486500
# max       43.291000     43.478000     42.792000     43.278000  684476.828000
#
#          close_time      quote_av        trades     tb_base_av   tb_quote_av  \
# count  1.126200e+04  1.126200e+04  11262.000000   11262.000000  1.126200e+04
# mean   1.597122e+12  1.326382e+05    265.891582    8688.201275  6.771253e+04
# std    1.172268e+10  3.953587e+05    494.408538   23982.502491  2.162287e+05
# min    1.576814e+12  0.000000e+00      0.000000       0.000000  0.000000e+00
# 25%    1.586974e+12  5.622410e+03     29.000000     574.767250  1.804626e+03
# 50%    1.597127e+12  2.337599e+04    105.500000    2368.902500  9.204391e+03
# 75%    1.607266e+12  9.219438e+04    299.000000    7528.574500  4.651260e+04
# max    1.617422e+12  1.310315e+07  15719.000000  544208.990000  6.960029e+06
#
#         ignore
# count  11262.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
test = df.drop(df.head(9102).index)
test = test.dropna()
df = df.drop(df.head(14118).index)
df = df.drop(df.tail(8760).index)
df = df.dropna()

# %%
test.describe()
# Out:
#                open          high           low         close        volume  \
# count   8760.000000   8760.000000   8760.000000   8760.000000   8760.000000
# mean   20149.671427  20279.888685  20010.123908  20155.685674   3050.132684
# std    15513.232142  15646.134950  15374.333263  15518.119601   2458.876456
# min     6182.380000   6212.000000   6150.110000   6182.380000      0.000000
# 25%     9497.900000   9532.870000   9460.750000   9498.012500   1633.862701
# 50%    11609.115000  11644.230000  11567.105000  11609.650000   2380.406326
# 75%    28419.480000  28657.845000  28157.420000  28512.895000   3611.955465
# max    61648.260000  61844.000000  61089.980000  61648.260000  47255.762685
#
#          close_time      quote_av         trades    tb_base_av   tb_quote_av  \
# count  8.760000e+03  8.760000e+03    8760.000000   8760.000000  8.760000e+03
# mean   1.601465e+12  6.646575e+07   52064.419178   1487.992437  3.267350e+07
# std    9.115856e+09  8.002566e+07   39658.828872   1229.719902  4.006709e+07
# min    1.585678e+12  0.000000e+00       0.000000      0.000000  0.000000e+00
# 25%    1.593579e+12  1.734669e+07   24239.250000    777.868793  8.235792e+06
# 50%    1.601462e+12  3.331203e+07   39645.000000   1154.674432  1.596130e+07
# 75%    1.609363e+12  9.180945e+07   68721.750000   1761.071895  4.488612e+07
# max    1.617253e+12  1.252120e+09  554876.000000  19709.376580  6.363879e+08
#
#        ignore
# count  8760.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count   8760.000000   8760.000000   8760.000000   8760.000000   8760.000000
# mean    8460.490769   8504.574449   8412.640736   8460.740598   2266.568157
# std     1810.084017   1820.448296   1797.275903   1809.598423   2406.557334
# min     4097.000000   4105.590000   3782.130000   4097.000000      0.000000
# 25%     7308.162500   7340.000000   7277.847500   7307.697500    990.868080
# 50%     8495.130000   8533.230000   8461.950000   8494.525000   1559.030637
# 75%     9819.130000   9868.362500   9771.177500   9817.290000   2582.317745
# max    13960.760000  13970.000000  13650.000000  13960.760000  41434.059072
#
#          close_time      quote_av         trades    tb_base_av   tb_quote_av  \
# count  8.760000e+03  8.760000e+03    8760.000000   8760.000000  8.760000e+03
# mean   1.569861e+12  1.888749e+07   19882.469406   1140.513486  9.515149e+06
# std    9.132607e+09  1.873445e+07   15467.367932   1176.034383  9.224459e+06
# min    1.554037e+12  0.000000e+00       0.000000      0.000000  0.000000e+00
# 25%    1.561956e+12  8.138774e+06   10884.500000    506.443635  4.190848e+06
# 50%    1.569868e+12  1.312371e+07   15476.500000    792.025643  6.663701e+06
# 75%    1.577766e+12  2.236885e+07   23380.750000   1323.435629  1.137441e+07
# max    1.585674e+12  2.243457e+08  196931.000000  20628.794047  1.390818e+08
#
#        ignore
# count  8760.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model():
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights


class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.close.values.tolist()
window_size = 168
skip = 1
initial_money = 10000

model = Model(window_size, 2200, 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations=500, checkpoint=10)


states_buy, states_sell, total_gains, invest = agent.buy()

fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
# Out:
# iter 10. reward: 13.290500
# iter 20. reward: 74.229900
# iter 30. reward: 48.382100
# iter 40. reward: 67.430300
# iter 50. reward: 151.822200
# iter 60. reward: 222.735200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3e524b7fa6bd> in <module>
#      10               skip = skip,
#      11               initial_money = initial_money)
# ---> 12 agent.fit(iterations=500, checkpoint=10)
#      13
#      14
#
# <ipython-input-8-90c96510e4b2> in fit(self, iterations, checkpoint)
#     131
#     132     def fit(self, iterations, checkpoint):
# --> 133         self.es.train(iterations, print_every = checkpoint)
#     134
#     135     def buy(self):
#
# <ipython-input-8-90c96510e4b2> in train(self, epoch, print_every)
#      36                     self.weights, population[k]
#      37                 )
# ---> 38                 rewards[k] = self.reward_function(weights_population)
#      39             rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
#      40             for index, w in enumerate(self.weights):
#
# <ipython-input-8-90c96510e4b2> in get_reward(self, weights)
#     116         quantity = 0
#     117         for t in range(0, len(self.trend) - 1, self.skip):
# --> 118             action = self.act(state)
#     119             next_state = self.get_state(t + 1)
#     120
#
# <ipython-input-8-90c96510e4b2> in act(self, sequence)
#      96
#      97     def act(self, sequence):
# ---> 98         decision = self.model.predict(np.array(sequence))
#      99         return np.argmax(decision[0])
#     100
#
# <ipython-input-8-90c96510e4b2> in predict(self, inputs)
#      63
#      64     def predict(self, inputs):
# ---> 65         feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
#      66         decision = np.dot(feed, self.weights[1])
#      67         return decision
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
close = test.close.values.tolist()
window_size = 30
skip = 1
initial_money = 100000
model = Model(window_size, 500, 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
states_buy, states_sell, total_gains, invest = agent.buy()

fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
# Out:
# day 4: buy 1 unit at price 6442.610000, total balance 93557.390000
# day 5: buy 1 unit at price 6431.550000, total balance 87125.840000
# day 6: buy 1 unit at price 6410.440000, total balance 80715.400000
# day 7: buy 1 unit at price 6305.120000, total balance 74410.280000
# day 8: buy 1 unit at price 6293.640000, total balance 68116.640000
# day 12: buy 1 unit at price 6304.460000, total balance 61812.180000
# day 13, sell 1 unit at price 6299.790000, investment -2.216803 %, total balance 68111.970000,
# day 14, sell 1 unit at price 6331.960000, investment -1.548460 %, total balance 74443.930000,
# day 16, sell 1 unit at price 6300.000000, investment -1.722815 %, total balance 80743.930000,
# day 17, sell 1 unit at price 6291.710000, investment -0.212684 %, total balance 87035.640000,
# day 20: buy 1 unit at price 6206.390000, total balance 80829.250000
# day 21, sell 1 unit at price 6251.130000, investment -0.675444 %, total balance 87080.380000,
# day 23: buy 1 unit at price 6182.380000, total balance 80898.000000
# day 24: buy 1 unit at price 6194.570000, total balance 74703.430000
# day 25, sell 1 unit at price 6186.860000, investment -1.865346 %, total balance 80890.290000,
# day 28, sell 1 unit at price 6354.000000, investment 2.378355 %, total balance 87244.290000,
# day 29, sell 1 unit at price 6520.750000, investment 5.473135 %, total balance 93765.040000,
# day 30, sell 1 unit at price 6642.920000, investment 7.237791 %, total balance 100407.960000,
# day 33: buy 1 unit at price 6604.930000, total balance 93803.030000
# day 36: buy 1 unit at price 6607.410000, total balance 87195.620000
# day 37: buy 1 unit at price 6639.650000, total balance 80555.970000
# day 39: buy 1 unit at price 6650.500000, total balance 73905.470000
# day 40: buy 1 unit at price 6638.710000, total balance 67266.760000
# day 41, sell 1 unit at price 6649.980000, investment 0.682066 %, total balance 73916.740000,
# day 42: buy 1 unit at price 6690.600000, total balance 67226.140000
# day 43: buy 1 unit at price 6656.760000, total balance 60569.380000
# day 44: buy 1 unit at price 6643.490000, total balance 53925.890000
# day 45, sell 1 unit at price 6775.100000, investment 2.537908 %, total balance 60700.990000,
# day 47: buy 1 unit at price 6916.620000, total balance 53784.370000
# day 48, sell 1 unit at price 7083.960000, investment 6.691768 %, total balance 60868.330000,
# day 49: buy 1 unit at price 6788.630000, total balance 54079.700000
# day 50: buy 1 unit at price 6803.250000, total balance 47276.450000
# day 51: buy 1 unit at price 6739.440000, total balance 40537.010000
# day 54: buy 1 unit at price 6794.090000, total balance 33742.920000
# day 56: buy 1 unit at price 6800.370000, total balance 26942.550000
# day 59: buy 1 unit at price 6784.600000, total balance 20157.950000
# day 60: buy 1 unit at price 6778.190000, total balance 13379.760000
# day 61, sell 1 unit at price 6797.870000, investment 2.215924 %, total balance 20177.630000,
# day 63, sell 1 unit at price 6925.680000, investment 4.322677 %, total balance 27103.310000,
# day 64, sell 1 unit at price 6958.820000, investment 4.008908 %, total balance 34062.130000,
# day 65: buy 1 unit at price 7015.690000, total balance 27046.440000
# day 68: buy 1 unit at price 6843.380000, total balance 20203.060000
# day 70: buy 1 unit at price 6711.900000, total balance 13491.160000
# day 71: buy 1 unit at price 6751.960000, total balance 6739.200000
# day 72, sell 1 unit at price 6716.560000, investment 0.898335 %, total balance 13455.760000,
# day 74: buy 1 unit at price 6768.150000, total balance 6687.610000
# day 75, sell 1 unit at price 6694.060000, investment 0.761196 %, total balance 13381.670000,
# day 77: buy 1 unit at price 6764.650000, total balance 6617.020000
# day 78, sell 1 unit at price 6734.100000, investment -2.638861 %, total balance 13351.120000,
# day 79, sell 1 unit at price 6754.440000, investment -0.503636 %, total balance 20105.560000,
# day 83: buy 1 unit at price 6715.380000, total balance 13390.180000
# day 86: buy 1 unit at price 6729.540000, total balance 6660.640000
# day 89, sell 1 unit at price 6873.180000, investment 1.027891 %, total balance 13533.820000,
# day 91: buy 1 unit at price 6710.080000, total balance 6823.740000
# day 92, sell 1 unit at price 6727.000000, investment -0.184585 %, total balance 13550.740000,
# day 95: buy 1 unit at price 6783.140000, total balance 6767.600000
# day 96, sell 1 unit at price 6775.860000, investment -0.268321 %, total balance 13543.460000,
# day 97, sell 1 unit at price 6771.310000, investment -0.427330 %, total balance 20314.770000,
# day 98, sell 1 unit at price 6747.350000, investment -0.549038 %, total balance 27062.120000,
# day 99, sell 1 unit at price 6825.670000, investment 0.700482 %, total balance 33887.790000,
# day 100, sell 1 unit at price 6860.130000, investment -2.217316 %, total balance 40747.920000,
# day 102: buy 1 unit at price 6856.990000, total balance 33890.930000
# day 103: buy 1 unit at price 6858.380000, total balance 27032.550000
# day 104, sell 1 unit at price 6850.900000, investment 0.109887 %, total balance 33883.450000,
# day 106: buy 1 unit at price 6797.030000, total balance 27086.420000
# day 107, sell 1 unit at price 6776.010000, investment 0.955169 %, total balance 33862.430000,
# day 109: buy 1 unit at price 6774.370000, total balance 27088.060000
# day 111: buy 1 unit at price 6782.930000, total balance 20305.130000
# day 112, sell 1 unit at price 6774.510000, investment 0.333977 %, total balance 27079.640000,
# day 113, sell 1 unit at price 6750.930000, investment -0.254427 %, total balance 33830.570000,
# day 114: buy 1 unit at price 6776.600000, total balance 27053.970000
# day 115, sell 1 unit at price 6789.000000, investment 0.359959 %, total balance 33842.970000,
# day 118: buy 1 unit at price 6784.740000, total balance 27058.230000
# day 119, sell 1 unit at price 6785.750000, investment 1.047893 %, total balance 33843.980000,
# day 122: buy 1 unit at price 6792.990000, total balance 27050.990000
# day 126, sell 1 unit at price 6772.780000, investment 0.642540 %, total balance 33823.770000,
# day 127, sell 1 unit at price 6865.850000, investment 2.321433 %, total balance 40689.620000,
# day 129: buy 1 unit at price 6824.990000, total balance 33864.630000
# day 130, sell 1 unit at price 6843.820000, investment 0.894571 %, total balance 40708.450000,
# day 131: buy 1 unit at price 6941.630000, total balance 33766.820000
# day 133: buy 1 unit at price 7079.000000, total balance 26687.820000
# day 134: buy 1 unit at price 7031.540000, total balance 19656.280000
# day 135, sell 1 unit at price 7038.950000, investment 2.653642 %, total balance 26695.230000,
# day 137: buy 1 unit at price 7077.130000, total balance 19618.100000
# day 138: buy 1 unit at price 7099.000000, total balance 12519.100000
# day 139: buy 1 unit at price 7134.540000, total balance 5384.560000
# day 144, sell 1 unit at price 7205.480000, investment 5.060962 %, total balance 12590.040000,
# day 145: buy 1 unit at price 7240.940000, total balance 5349.100000
# day 146, sell 1 unit at price 7265.860000, investment 6.897571 %, total balance 12614.960000,
# day 147: buy 1 unit at price 7215.970000, total balance 5398.990000
# day 152, sell 1 unit at price 7348.860000, investment 8.480346 %, total balance 12747.850000,
# day 154: buy 1 unit at price 7322.070000, total balance 5425.780000
# day 163, sell 1 unit at price 7336.260000, investment 8.157684 %, total balance 12762.040000,
# day 164: buy 1 unit at price 7348.360000, total balance 5413.680000
# day 169, sell 1 unit at price 7303.610000, investment 7.776909 %, total balance 12717.290000,
# day 170: buy 1 unit at price 7287.550000, total balance 5429.740000
# day 175, sell 1 unit at price 7156.660000, investment 5.481713 %, total balance 12586.400000,
# day 176: buy 1 unit at price 7162.720000, total balance 5423.680000
# day 177, sell 1 unit at price 7265.770000, investment 6.959822 %, total balance 12689.450000,
# day 178, sell 1 unit at price 7353.410000, investment 7.742429 %, total balance 20042.860000,
# day 180: buy 1 unit at price 7412.170000, total balance 12630.690000
# day 181: buy 1 unit at price 7317.650000, total balance 5313.040000
# day 185, sell 1 unit at price 7248.230000, investment 4.416830 %, total balance 12561.270000,
# day 186: buy 1 unit at price 7292.920000, total balance 5268.350000
# day 191, sell 1 unit at price 7322.680000, investment 3.442294 %, total balance 12591.030000,
# day 192: buy 1 unit at price 7307.950000, total balance 5283.080000
# day 193, sell 1 unit at price 7319.460000, investment 4.094693 %, total balance 12602.540000,
# day 194, sell 1 unit at price 7306.090000, investment 3.235210 %, total balance 19908.630000,
# day 197, sell 1 unit at price 7358.380000, investment 3.653754 %, total balance 27267.010000,
# day 199: buy 1 unit at price 7346.910000, total balance 19920.100000
# day 200, sell 1 unit at price 7311.900000, investment 2.485935 %, total balance 27232.000000,
# day 201: buy 1 unit at price 7318.490000, total balance 19913.510000
# day 203: buy 1 unit at price 7288.510000, total balance 12625.000000
# day 204, sell 1 unit at price 7307.880000, investment 0.924466 %, total balance 19932.880000,
# day 207: buy 1 unit at price 7330.010000, total balance 12602.870000
# day 209: buy 1 unit at price 7306.710000, total balance 5296.160000
# day 210, sell 1 unit at price 7183.980000, investment -0.443322 %, total balance 12480.140000,
# day 211: buy 1 unit at price 7303.030000, total balance 5177.110000
# day 214, sell 1 unit at price 7282.680000, investment -0.537963 %, total balance 12459.790000,
# day 215: buy 1 unit at price 7280.750000, total balance 5179.040000
# day 216, sell 1 unit at price 7295.050000, investment -0.725468 %, total balance 12474.090000,
# day 218: buy 1 unit at price 7262.850000, total balance 5211.240000
# day 219, sell 1 unit at price 7295.310000, investment 0.106483 %, total balance 12506.550000,
# day 222, sell 1 unit at price 7283.540000, investment 1.686789 %, total balance 19790.090000,
# day 223, sell 1 unit at price 7292.800000, investment -1.610460 %, total balance 27082.890000,
# day 224, sell 1 unit at price 7262.310000, investment -0.756254 %, total balance 34345.200000,
# day 226: buy 1 unit at price 7175.780000, total balance 27169.420000
# day 227: buy 1 unit at price 7140.060000, total balance 20029.360000
# day 229: buy 1 unit at price 6957.020000, total balance 13072.340000
# day 231, sell 1 unit at price 6918.270000, investment -5.137174 %, total balance 19990.610000,
# day 233: buy 1 unit at price 6934.580000, total balance 13056.030000
# day 234, sell 1 unit at price 6898.240000, investment -5.606360 %, total balance 19954.270000,
# day 235, sell 1 unit at price 6921.530000, investment -5.789917 %, total balance 26875.800000,
# day 236, sell 1 unit at price 6894.970000, investment -5.786986 %, total balance 33770.770000,
# day 237, sell 1 unit at price 6846.710000, investment -6.061596 %, total balance 40617.480000,
# day 238, sell 1 unit at price 6766.430000, investment -7.688666 %, total balance 47383.910000,
# day 239, sell 1 unit at price 6857.540000, investment -6.147363 %, total balance 54241.450000,
# day 242, sell 1 unit at price 6900.310000, investment -5.514423 %, total balance 61141.760000,
# day 243, sell 1 unit at price 6909.990000, investment -5.092333 %, total balance 68051.750000,
# day 244, sell 1 unit at price 6894.430000, investment -5.072664 %, total balance 74946.180000,
# day 245: buy 1 unit at price 6855.010000, total balance 68091.170000
# day 246, sell 1 unit at price 6858.920000, investment -4.415687 %, total balance 74950.090000,
# day 247: buy 1 unit at price 6903.730000, total balance 68046.360000
# day 249: buy 1 unit at price 6908.620000, total balance 61137.740000
# day 250, sell 1 unit at price 6907.820000, investment -3.252634 %, total balance 68045.560000,
# day 251, sell 1 unit at price 6907.140000, investment -0.716974 %, total balance 74952.700000,
# day 252, sell 1 unit at price 6924.230000, investment -0.149252 %, total balance 81876.930000,
# day 253: buy 1 unit at price 6920.870000, total balance 74956.060000
# day 254, sell 1 unit at price 6876.700000, investment 0.316411 %, total balance 81832.760000,
# day 255: buy 1 unit at price 6879.150000, total balance 74953.610000
# day 256, sell 1 unit at price 6854.080000, investment -0.719176 %, total balance 81807.690000,
# day 257, sell 1 unit at price 6837.880000, investment -1.023938 %, total balance 88645.570000,
# day 258, sell 1 unit at price 6878.210000, investment -0.616396 %, total balance 95523.780000,
# day 259, sell 1 unit at price 6874.560000, investment -0.066723 %, total balance 102398.340000,
# day 261: buy 1 unit at price 6815.690000, total balance 95582.650000
# day 262: buy 1 unit at price 6831.280000, total balance 88751.370000
# day 263, sell 1 unit at price 6811.640000, investment -0.059422 %, total balance 95563.010000,
# day 264: buy 1 unit at price 6785.720000, total balance 88777.290000
# day 265: buy 1 unit at price 6811.100000, total balance 81966.190000
# day 266, sell 1 unit at price 6803.220000, investment -0.410758 %, total balance 88769.410000,
# day 270: buy 1 unit at price 6876.830000, total balance 81892.580000
# day 271, sell 1 unit at price 6866.000000, investment 1.183073 %, total balance 88758.580000,
# day 272: buy 1 unit at price 6846.480000, total balance 81912.100000
# day 273, sell 1 unit at price 6820.840000, investment 0.143002 %, total balance 88732.940000,
# day 278: buy 1 unit at price 6828.640000, total balance 81904.300000
# day 279, sell 1 unit at price 6829.000000, investment -0.695524 %, total balance 88733.300000,
# day 280: buy 1 unit at price 6841.400000, total balance 81891.900000
# day 281: buy 1 unit at price 6833.400000, total balance 75058.500000
# day 282: buy 1 unit at price 6847.180000, total balance 68211.320000
# day 283, sell 1 unit at price 6910.030000, investment 0.928214 %, total balance 75121.350000,
# day 285, sell 1 unit at price 6966.900000, investment 2.024708 %, total balance 82088.250000,
# day 286, sell 1 unit at price 7018.990000, investment 2.595814 %, total balance 89107.240000,
# day 287, sell 1 unit at price 7142.340000, investment 4.521029 %, total balance 96249.580000,
# day 288, sell 1 unit at price 7091.690000, investment 3.570959 %, total balance 103341.270000,
# day 289: buy 1 unit at price 7097.230000, total balance 96244.040000
# day 290: buy 1 unit at price 7112.130000, total balance 89131.910000
# day 291: buy 1 unit at price 7102.320000, total balance 82029.590000
# day 293: buy 1 unit at price 7028.460000, total balance 75001.130000
# day 294: buy 1 unit at price 6903.790000, total balance 68097.340000
# day 295: buy 1 unit at price 6718.850000, total balance 61378.490000
# day 296: buy 1 unit at price 6692.110000, total balance 54686.380000
# day 299: buy 1 unit at price 6687.460000, total balance 47998.920000
# day 300, sell 1 unit at price 6693.070000, investment -5.694616 %, total balance 54691.990000,
# day 301, sell 1 unit at price 6735.580000, investment -5.294476 %, total balance 61427.570000,
# day 302, sell 1 unit at price 6699.340000, investment -5.673921 %, total balance 68126.910000,
# day 303, sell 1 unit at price 6702.600000, investment -4.636293 %, total balance 74829.510000,
# day 304, sell 1 unit at price 6685.470000, investment -3.162321 %, total balance 81514.980000,
# day 305, sell 1 unit at price 6718.950000, investment 0.001488 %, total balance 88233.930000,
# day 309: buy 1 unit at price 6716.010000, total balance 81517.920000
# day 312: buy 1 unit at price 6753.780000, total balance 74764.140000
# day 313: buy 1 unit at price 6749.960000, total balance 68014.180000
# day 314, sell 1 unit at price 6772.740000, investment 1.204852 %, total balance 74786.920000,
# day 316: buy 1 unit at price 6827.880000, total balance 67959.040000
# day 317, sell 1 unit at price 6871.110000, investment 2.746185 %, total balance 74830.150000,
# day 318, sell 1 unit at price 6837.910000, investment 1.815066 %, total balance 81668.060000,
# day 319: buy 1 unit at price 6827.490000, total balance 74840.570000
# day 320, sell 1 unit at price 6848.460000, investment 1.401882 %, total balance 81689.030000,
# day 321: buy 1 unit at price 6853.180000, total balance 74835.850000
# day 322, sell 1 unit at price 6885.070000, investment 2.001641 %, total balance 81720.920000,
# day 323: buy 1 unit at price 6884.320000, total balance 74836.600000
# day 324, sell 1 unit at price 6882.530000, investment 0.800395 %, total balance 81719.130000,
# day 325, sell 1 unit at price 6872.040000, investment 0.652509 %, total balance 88591.170000,
# day 326: buy 1 unit at price 6817.770000, total balance 81773.400000
# day 327: buy 1 unit at price 6782.140000, total balance 74991.260000
# day 328: buy 1 unit at price 6846.140000, total balance 68145.120000
# day 330, sell 1 unit at price 6827.820000, investment -0.370047 %, total balance 74972.940000,
# day 332: buy 1 unit at price 6887.890000, total balance 68085.050000
# day 333, sell 1 unit at price 6894.120000, investment 0.142352 %, total balance 74979.170000,
# day 335: buy 1 unit at price 6947.340000, total balance 68031.830000
# day 336, sell 1 unit at price 6920.000000, investment 1.499464 %, total balance 74951.830000,
# day 340: buy 1 unit at price 6851.450000, total balance 68100.380000
# day 341: buy 1 unit at price 6874.820000, total balance 61225.560000
# day 344: buy 1 unit at price 6877.560000, total balance 54348.000000
# day 347, sell 1 unit at price 6891.290000, investment 1.609374 %, total balance 61239.290000,
# day 348, sell 1 unit at price 6906.090000, investment 0.875676 %, total balance 68145.380000,
# day 349, sell 1 unit at price 6885.260000, investment -0.038183 %, total balance 75030.640000,
# day 351: buy 1 unit at price 6849.770000, total balance 68180.870000
# day 352, sell 1 unit at price 6839.000000, investment -1.559446 %, total balance 75019.870000,
# day 354: buy 1 unit at price 6783.000000, total balance 68236.870000
# day 355, sell 1 unit at price 6713.670000, investment -2.010961 %, total balance 74950.540000,
# day 358: buy 1 unit at price 6701.900000, total balance 68248.640000
# day 359, sell 1 unit at price 6729.580000, investment -2.112637 %, total balance 74978.220000,
# day 361, sell 1 unit at price 6748.230000, investment -1.880463 %, total balance 81726.450000,
# day 362, sell 1 unit at price 6730.010000, investment -1.748380 %, total balance 88456.460000,
# day 364, sell 1 unit at price 6727.400000, investment -0.819696 %, total balance 95183.860000,
# day 365, sell 1 unit at price 6708.960000, investment 0.105343 %, total balance 101892.820000,
# day 367: buy 1 unit at price 6573.150000, total balance 95319.670000
# day 368, sell 1 unit at price 6622.670000, investment 0.753368 %, total balance 101942.340000,
# day 371: buy 1 unit at price 6622.290000, total balance 95320.050000
# day 372, sell 1 unit at price 6631.850000, investment 0.144361 %, total balance 101951.900000,
# day 377: buy 1 unit at price 6952.820000, total balance 94999.080000
# day 378, sell 1 unit at price 7023.990000, investment 1.023613 %, total balance 102023.070000,
# day 381: buy 1 unit at price 7021.970000, total balance 95001.100000
# day 382: buy 1 unit at price 7045.510000, total balance 87955.590000
# day 385: buy 1 unit at price 7009.230000, total balance 80946.360000
# day 386, sell 1 unit at price 7070.790000, investment 0.695246 %, total balance 88017.150000,
# day 387: buy 1 unit at price 7047.530000, total balance 80969.620000
# day 388: buy 1 unit at price 7062.970000, total balance 73906.650000
# day 389, sell 1 unit at price 7152.930000, investment 1.524659 %, total balance 81059.580000,
# day 391: buy 1 unit at price 7062.160000, total balance 73997.420000
# day 392: buy 1 unit at price 7107.740000, total balance 66889.680000
# day 394, sell 1 unit at price 7086.180000, investment 1.097838 %, total balance 73975.860000,
# day 398: buy 1 unit at price 7043.380000, total balance 66932.480000
# day 401: buy 1 unit at price 7097.840000, total balance 59834.640000
# day 404: buy 1 unit at price 7059.400000, total balance 52775.240000
# day 405, sell 1 unit at price 7024.370000, investment -0.328626 %, total balance 59799.610000,
# day 406, sell 1 unit at price 7037.940000, investment -0.354383 %, total balance 66837.550000,
# day 409, sell 1 unit at price 7033.590000, investment -0.404550 %, total balance 73871.140000,
# day 411, sell 1 unit at price 7054.420000, investment -0.750168 %, total balance 80925.560000,
# day 412: buy 1 unit at price 7047.960000, total balance 73877.600000
# day 413, sell 1 unit at price 7054.720000, investment 0.161002 %, total balance 80932.320000,
# day 415: buy 1 unit at price 7066.430000, total balance 73865.890000
# day 416, sell 1 unit at price 7077.340000, investment -0.288820 %, total balance 80943.230000,
# day 418: buy 1 unit at price 7086.800000, total balance 73856.430000
# day 419, sell 1 unit at price 7081.000000, investment 0.305975 %, total balance 80937.430000,
# day 420, sell 1 unit at price 7100.710000, investment 0.748444 %, total balance 88038.140000,
# day 421: buy 1 unit at price 7085.710000, total balance 80952.430000
# day 423: buy 1 unit at price 7090.000000, total balance 73862.430000
# day 426, sell 1 unit at price 7104.520000, investment 0.539027 %, total balance 80966.950000,
# day 427, sell 1 unit at price 7133.340000, investment 0.656714 %, total balance 88100.290000,
# day 430: buy 1 unit at price 7243.370000, total balance 80856.920000
# day 431, sell 1 unit at price 7194.040000, investment 1.528852 %, total balance 88050.960000,
# day 432: buy 1 unit at price 7189.690000, total balance 80861.270000
# day 433, sell 1 unit at price 7191.770000, investment 1.435402 %, total balance 88053.040000,
# day 436: buy 1 unit at price 7215.600000, total balance 80837.440000
# day 439: buy 1 unit at price 7222.000000, total balance 73615.440000
# day 440: buy 1 unit at price 7226.430000, total balance 66389.010000
# day 441: buy 1 unit at price 7232.950000, total balance 59156.060000
# day 445: buy 1 unit at price 7154.640000, total balance 52001.420000
# day 449: buy 1 unit at price 7165.960000, total balance 44835.460000
# day 452: buy 1 unit at price 7103.200000, total balance 37732.260000
# day 453, sell 1 unit at price 7106.990000, investment -1.882825 %, total balance 44839.250000,
# day 457: buy 1 unit at price 7147.120000, total balance 37692.130000
# day 458, sell 1 unit at price 7134.280000, investment -0.770687 %, total balance 44826.410000,
# day 459: buy 1 unit at price 7136.440000, total balance 37689.970000
# day 460, sell 1 unit at price 7183.040000, investment -0.451245 %, total balance 44873.010000,
# day 461, sell 1 unit at price 7175.520000, investment -0.643589 %, total balance 52048.530000,
# day 463: buy 1 unit at price 7161.160000, total balance 44887.370000
# day 467, sell 1 unit at price 7173.570000, investment -0.731482 %, total balance 52060.940000,
# day 468, sell 1 unit at price 7173.290000, investment -0.824836 %, total balance 59234.230000,
# day 469: buy 1 unit at price 7167.970000, total balance 52066.260000
# day 471: buy 1 unit at price 7150.160000, total balance 44916.100000
# day 472: buy 1 unit at price 7146.560000, total balance 37769.540000
# day 473, sell 1 unit at price 7076.450000, investment -1.092857 %, total balance 44845.990000,
# day 474: buy 1 unit at price 6966.550000, total balance 37879.440000
# day 475, sell 1 unit at price 7034.110000, investment -1.839949 %, total balance 44913.550000,
# day 478, sell 1 unit at price 7071.400000, investment -0.447686 %, total balance 51984.950000,
# day 479: buy 1 unit at price 7044.730000, total balance 44940.220000
# day 480, sell 1 unit at price 6872.590000, investment -3.841128 %, total balance 51812.810000,
# day 481: buy 1 unit at price 6865.850000, total balance 44946.960000
# day 483, sell 1 unit at price 6856.940000, investment -3.916519 %, total balance 51803.900000,
# day 485: buy 1 unit at price 6875.630000, total balance 44928.270000
# day 486, sell 1 unit at price 6826.830000, investment -4.668657 %, total balance 51755.100000,
# day 487, sell 1 unit at price 6878.540000, investment -4.037824 %, total balance 58633.640000,
# day 488, sell 1 unit at price 6874.640000, investment -3.853340 %, total balance 65508.280000,
# day 489: buy 1 unit at price 6848.450000, total balance 58659.830000
# day 490: buy 1 unit at price 6857.920000, total balance 51801.910000
# day 491, sell 1 unit at price 6853.120000, investment -4.106031 %, total balance 58655.030000,
# day 494, sell 1 unit at price 6878.680000, investment -1.261313 %, total balance 65533.710000,
# day 495, sell 1 unit at price 6859.700000, investment -2.626502 %, total balance 72393.410000,
# day 496, sell 1 unit at price 6832.610000, investment -0.484135 %, total balance 79226.020000,
# day 498: buy 1 unit at price 6793.290000, total balance 72432.730000
# day 500, sell 1 unit at price 6834.270000, investment -0.601545 %, total balance 79267.000000,
# day 501: buy 1 unit at price 6816.370000, total balance 72450.630000
# day 502, sell 1 unit at price 6830.800000, investment -0.257723 %, total balance 79281.430000,
# day 503, sell 1 unit at price 6844.130000, investment -0.201081 %, total balance 86125.560000,
# day 504, sell 1 unit at price 6898.350000, investment 1.546526 %, total balance 93023.910000,
# day 505, sell 1 unit at price 6877.360000, investment 0.894758 %, total balance 99901.270000,
# day 506: buy 1 unit at price 6864.920000, total balance 93036.350000
# day 507: buy 1 unit at price 6884.080000, total balance 86152.270000
# day 508, sell 1 unit at price 6888.000000, investment 0.336202 %, total balance 93040.270000,
# day 509, sell 1 unit at price 6890.610000, investment 0.094857 %, total balance 99930.880000,
# day 510: buy 1 unit at price 6841.370000, total balance 93089.510000
# day 511, sell 1 unit at price 6831.680000, investment -0.141638 %, total balance 99921.190000,
# day 512: buy 1 unit at price 6854.050000, total balance 93067.140000
# day 514: buy 1 unit at price 6862.240000, total balance 86204.900000
# day 515, sell 1 unit at price 6854.070000, investment 0.000292 %, total balance 93058.970000,
# day 516: buy 1 unit at price 6900.560000, total balance 86158.410000
# day 517, sell 1 unit at price 6934.280000, investment 1.049803 %, total balance 93092.690000,
# day 519, sell 1 unit at price 6947.940000, investment 0.686611 %, total balance 100040.630000,
# day 521: buy 1 unit at price 6937.570000, total balance 93103.060000
# day 524, sell 1 unit at price 7061.340000, investment 1.784054 %, total balance 100164.400000,
# day 526: buy 1 unit at price 7112.200000, total balance 93052.200000
# day 527, sell 1 unit at price 7119.730000, investment 0.105874 %, total balance 100171.930000,
# day 528: buy 1 unit at price 7084.050000, total balance 93087.880000
# day 529: buy 1 unit at price 7096.340000, total balance 85991.540000
# day 530: buy 1 unit at price 7085.570000, total balance 78905.970000
# day 531: buy 1 unit at price 7108.590000, total balance 71797.380000
# day 533: buy 1 unit at price 7112.000000, total balance 64685.380000
# day 535, sell 1 unit at price 7116.820000, investment 0.462588 %, total balance 71802.200000,
# day 536: buy 1 unit at price 7169.620000, total balance 64632.580000
# day 537: buy 1 unit at price 7125.220000, total balance 57507.360000
# day 538: buy 1 unit at price 7113.270000, total balance 50394.090000
# day 539: buy 1 unit at price 7127.290000, total balance 43266.800000
# day 542: buy 1 unit at price 7061.540000, total balance 36205.260000
# day 544, sell 1 unit at price 7096.360000, investment 0.000282 %, total balance 43301.620000,
# day 546: buy 1 unit at price 7133.390000, total balance 36168.230000
# day 549, sell 1 unit at price 7536.360000, investment 6.362085 %, total balance 43704.590000,
# day 551, sell 1 unit at price 7504.910000, investment 5.575227 %, total balance 51209.500000,
# day 552: buy 1 unit at price 7551.140000, total balance 43658.360000
# day 553: buy 1 unit at price 7539.790000, total balance 36118.570000
# day 555: buy 1 unit at price 7531.870000, total balance 28586.700000
# day 556: buy 1 unit at price 7589.720000, total balance 20996.980000
# day 558: buy 1 unit at price 7482.390000, total balance 13514.590000
# day 559: buy 1 unit at price 7489.010000, total balance 6025.580000
# day 560, sell 1 unit at price 7482.010000, investment 5.202615 %, total balance 13507.590000,
# day 561: buy 1 unit at price 7520.070000, total balance 5987.520000
# day 564, sell 1 unit at price 7495.590000, investment 4.546545 %, total balance 13483.110000,
# day 565: buy 1 unit at price 7531.090000, total balance 5952.020000
# day 566, sell 1 unit at price 7568.680000, investment 6.223808 %, total balance 13520.700000,
# day 567, sell 1 unit at price 7555.890000, investment 6.222455 %, total balance 21076.590000,
# day 569: buy 1 unit at price 7533.630000, total balance 13542.960000
# day 572: buy 1 unit at price 7478.300000, total balance 6064.660000
# day 576, sell 1 unit at price 7505.680000, investment 5.309031 %, total balance 13570.340000,
# day 578: buy 1 unit at price 7521.580000, total balance 6048.760000
# day 579, sell 1 unit at price 7524.490000, investment 6.555935 %, total balance 13573.250000,
# day 580, sell 1 unit at price 7495.320000, investment 5.073745 %, total balance 21068.570000,
# day 581: buy 1 unit at price 7485.540000, total balance 13583.030000
# day 583, sell 1 unit at price 7471.350000, investment -1.056662 %, total balance 21054.380000,
# day 585: buy 1 unit at price 7518.420000, total balance 13535.960000
# day 586, sell 1 unit at price 7563.450000, investment 0.313802 %, total balance 21099.410000,
# day 587, sell 1 unit at price 7578.390000, investment 0.617642 %, total balance 28677.800000,
# day 588: buy 1 unit at price 7561.480000, total balance 21116.320000
# day 589: buy 1 unit at price 7550.520000, total balance 13565.800000
# day 590, sell 1 unit at price 7560.560000, investment -0.384204 %, total balance 21126.360000,
# day 592, sell 1 unit at price 7532.970000, investment 0.675987 %, total balance 28659.330000,
# day 593, sell 1 unit at price 7551.560000, investment 0.835224 %, total balance 36210.890000,
# day 597: buy 1 unit at price 7548.000000, total balance 28662.890000
# day 598, sell 1 unit at price 7539.570000, investment 0.259306 %, total balance 36202.460000,
# day 600: buy 1 unit at price 7542.810000, total balance 28659.650000
# day 601, sell 1 unit at price 7544.690000, investment 0.180585 %, total balance 36204.340000,
# day 602, sell 1 unit at price 7523.120000, investment -0.139508 %, total balance 43727.460000,
# day 604: buy 1 unit at price 7538.670000, total balance 36188.790000
# day 605, sell 1 unit at price 7563.080000, investment 1.133680 %, total balance 43751.870000,
# day 607: buy 1 unit at price 7565.700000, total balance 36186.170000
# day 608: buy 1 unit at price 7565.710000, total balance 28620.460000
# day 609, sell 1 unit at price 7555.000000, investment 0.444322 %, total balance 36175.460000,
# day 611: buy 1 unit at price 7550.250000, total balance 28625.210000
# day 617: buy 1 unit at price 7645.000000, total balance 20980.210000
# day 618, sell 1 unit at price 7680.110000, investment 2.599278 %, total balance 28660.320000,
# day 620: buy 1 unit at price 7545.010000, total balance 21115.310000
# day 621: buy 1 unit at price 7564.090000, total balance 13551.220000
# day 624, sell 1 unit at price 7646.630000, investment 1.705279 %, total balance 21197.850000,
# day 625: buy 1 unit at price 7643.290000, total balance 13554.560000
# day 626, sell 1 unit at price 7624.600000, investment 0.834757 %, total balance 21179.160000,
# day 627: buy 1 unit at price 7611.560000, total balance 13567.600000
# day 628: buy 1 unit at price 7693.100000, total balance 5874.500000
# day 639, sell 1 unit at price 7691.930000, investment 1.872851 %, total balance 13566.430000,
# day 640: buy 1 unit at price 7717.890000, total balance 5848.540000
# day 642, sell 1 unit at price 7690.360000, investment 1.886063 %, total balance 13538.900000,
# day 644: buy 1 unit at price 7675.580000, total balance 5863.320000
# day 648, sell 1 unit at price 7698.320000, investment 2.061698 %, total balance 13561.640000,
# day 649, sell 1 unit at price 7694.300000, investment 2.064423 %, total balance 21255.940000,
# day 651: buy 1 unit at price 7760.370000, total balance 13495.570000
# day 654: buy 1 unit at price 7690.010000, total balance 5805.560000
# day 655, sell 1 unit at price 7702.190000, investment 1.804063 %, total balance 13507.750000,
# day 658: buy 1 unit at price 7696.770000, total balance 5810.980000
# day 663, sell 1 unit at price 7743.360000, investment 2.348094 %, total balance 13554.340000,
# day 664, sell 1 unit at price 7728.620000, investment 2.362438 %, total balance 21282.960000,
# day 665: buy 1 unit at price 7753.770000, total balance 13529.190000
# day 666, sell 1 unit at price 7727.100000, investment 1.073905 %, total balance 21256.290000,
# day 667, sell 1 unit at price 7683.410000, investment 1.834325 %, total balance 28939.700000,
# day 669: buy 1 unit at price 7725.010000, total balance 21214.690000
# day 670, sell 1 unit at price 7726.260000, investment 2.143946 %, total balance 28940.950000,
# day 671: buy 1 unit at price 7733.960000, total balance 21206.990000
# day 672: buy 1 unit at price 7717.040000, total balance 13489.950000
# day 674: buy 1 unit at price 7728.080000, total balance 5761.870000
# day 678, sell 1 unit at price 7759.150000, investment 1.515839 %, total balance 13521.020000,
# day 681: buy 1 unit at price 7841.230000, total balance 5679.790000
# day 682, sell 1 unit at price 7863.000000, investment 3.303396 %, total balance 13542.790000,
# day 683, sell 1 unit at price 7945.600000, investment 3.282162 %, total balance 21488.390000,
# day 685: buy 1 unit at price 7942.990000, total balance 13545.400000
# day 686, sell 1 unit at price 7977.890000, investment 3.368796 %, total balance 21523.290000,
# day 689: buy 1 unit at price 8242.560000, total balance 13280.730000
# day 690, sell 1 unit at price 8295.680000, investment 8.078868 %, total balance 21576.410000,
# day 691: buy 1 unit at price 8350.120000, total balance 13226.290000
# day 692: buy 1 unit at price 8357.060000, total balance 4869.230000
# day 704, sell 1 unit at price 9288.980000, investment 19.697643 %, total balance 14158.210000,
# day 706: buy 1 unit at price 9363.130000, total balance 4795.080000
# day 714, sell 1 unit at price 8853.370000, investment 15.128199 %, total balance 13648.450000,
# day 715: buy 1 unit at price 8827.970000, total balance 4820.480000
# day 717, sell 1 unit at price 8689.300000, investment 12.895409 %, total balance 13509.780000,
# day 718: buy 1 unit at price 8552.220000, total balance 4957.560000
# day 719, sell 1 unit at price 8669.940000, investment 11.815801 %, total balance 13627.500000,
# day 723: buy 1 unit at price 8759.770000, total balance 4867.730000
# day 724, sell 1 unit at price 8620.000000, investment 11.585616 %, total balance 13487.730000,
# day 726: buy 1 unit at price 8662.610000, total balance 4825.120000
# day 731, sell 1 unit at price 8756.900000, investment 13.226601 %, total balance 13582.020000,
# day 733: buy 1 unit at price 8794.020000, total balance 4788.000000
# day 736, sell 1 unit at price 8995.660000, investment 16.568788 %, total balance 13783.660000,
# day 737: buy 1 unit at price 8878.530000, total balance 4905.130000
# day 738, sell 1 unit at price 8792.200000, investment 13.769526 %, total balance 13697.330000,
# day 739, sell 1 unit at price 8823.170000, investment 12.522780 %, total balance 22520.500000,
# day 740: buy 1 unit at price 8726.840000, total balance 13793.660000
# day 742: buy 1 unit at price 8762.740000, total balance 5030.920000
# day 744, sell 1 unit at price 8727.820000, investment 9.880788 %, total balance 13758.740000,
# day 745: buy 1 unit at price 8729.040000, total balance 5029.700000
# day 746, sell 1 unit at price 8844.670000, investment 7.304891 %, total balance 13874.370000,
# day 747, sell 1 unit at price 8837.150000, investment 5.832611 %, total balance 22711.520000,
# day 748: buy 1 unit at price 8826.960000, total balance 13884.560000
# day 749: buy 1 unit at price 8827.990000, total balance 5056.570000
# day 750, sell 1 unit at price 8792.170000, investment 5.206496 %, total balance 13848.740000,
# day 752: buy 1 unit at price 8834.080000, total balance 5014.660000
# day 760, sell 1 unit at price 8834.000000, investment -5.651209 %, total balance 13848.660000,
# day 761, sell 1 unit at price 8859.350000, investment 0.355461 %, total balance 22708.010000,
# day 762, sell 1 unit at price 8899.730000, investment 4.063389 %, total balance 31607.740000,
# day 763, sell 1 unit at price 8919.510000, investment 1.823564 %, total balance 40527.250000,
# day 765: buy 1 unit at price 8980.630000, total balance 31546.620000
# day 766, sell 1 unit at price 8971.980000, investment 3.571326 %, total balance 40518.600000,
# day 768: buy 1 unit at price 8878.110000, total balance 31640.490000
# day 769, sell 1 unit at price 8930.530000, investment 1.552305 %, total balance 40571.020000,
# day 771: buy 1 unit at price 8933.540000, total balance 31637.480000
# day 772: buy 1 unit at price 8972.050000, total balance 22665.430000
# day 773, sell 1 unit at price 9124.350000, investment 2.768702 %, total balance 31789.780000,
# day 775: buy 1 unit at price 9073.060000, total balance 22716.720000
# day 776, sell 1 unit at price 9132.950000, investment 4.653574 %, total balance 31849.670000,
# day 777: buy 1 unit at price 9112.260000, total balance 22737.410000
# day 779: buy 1 unit at price 9003.000000, total balance 13734.410000
# day 780: buy 1 unit at price 8990.750000, total balance 4743.660000
# day 789, sell 1 unit at price 8852.140000, investment 1.020229 %, total balance 13595.800000,
# day 792, sell 1 unit at price 8872.340000, investment 1.641647 %, total balance 22468.140000,
# day 793, sell 1 unit at price 8843.550000, investment 0.187947 %, total balance 31311.690000,
# day 795: buy 1 unit at price 8895.700000, total balance 22415.990000
# day 796, sell 1 unit at price 8894.160000, investment 0.749548 %, total balance 31310.150000,
# day 798: buy 1 unit at price 8693.710000, total balance 22616.440000
# day 799, sell 1 unit at price 8746.700000, investment -0.989124 %, total balance 31363.140000,
# day 802: buy 1 unit at price 8606.110000, total balance 22757.030000
# day 803: buy 1 unit at price 8620.800000, total balance 14136.230000
# day 806, sell 1 unit at price 8630.540000, investment -3.898279 %, total balance 22766.770000,
# day 807, sell 1 unit at price 8623.460000, investment -2.868291 %, total balance 31390.230000,
# day 808, sell 1 unit at price 8672.360000, investment -2.923589 %, total balance 40062.590000,
# day 809, sell 1 unit at price 8714.580000, investment -2.869690 %, total balance 48777.170000,
# day 811: buy 1 unit at price 8780.100000, total balance 39997.070000
# day 812, sell 1 unit at price 8848.000000, investment -2.480530 %, total balance 48845.070000,
# day 813, sell 1 unit at price 8828.960000, investment -3.108998 %, total balance 57674.030000,
# day 815, sell 1 unit at price 8845.400000, investment -1.750528 %, total balance 66519.430000,
# day 816, sell 1 unit at price 8830.140000, investment -1.786392 %, total balance 75349.570000,
# day 818: buy 1 unit at price 8936.710000, total balance 66412.860000
# day 819: buy 1 unit at price 8869.930000, total balance 57542.930000
# day 820, sell 1 unit at price 8871.960000, investment -0.266871 %, total balance 66414.890000,
# day 821: buy 1 unit at price 8901.650000, total balance 57513.240000
# day 822: buy 1 unit at price 8879.580000, total balance 48633.660000
# day 823, sell 1 unit at price 8853.750000, investment 1.840871 %, total balance 57487.410000,
# day 824: buy 1 unit at price 8850.000000, total balance 48637.410000
# day 825, sell 1 unit at price 9043.800000, investment 5.085805 %, total balance 57681.210000,
# day 826, sell 1 unit at price 9006.450000, investment 4.473483 %, total balance 66687.660000,
# day 827: buy 1 unit at price 9024.980000, total balance 57662.680000
# day 828: buy 1 unit at price 9013.550000, total balance 48649.130000
# day 829, sell 1 unit at price 9032.570000, investment 2.875480 %, total balance 57681.700000,
# day 830, sell 1 unit at price 9000.010000, investment 0.708314 %, total balance 66681.710000,
# day 831: buy 1 unit at price 8848.250000, total balance 57833.460000
# day 832: buy 1 unit at price 8844.730000, total balance 48988.730000
# day 836, sell 1 unit at price 8842.340000, investment -0.311051 %, total balance 57831.070000,
# day 837, sell 1 unit at price 8872.110000, investment -0.331849 %, total balance 66703.180000,
# day 840, sell 1 unit at price 8905.000000, investment 0.286275 %, total balance 75608.180000,
# day 841: buy 1 unit at price 8938.050000, total balance 66670.130000
# day 842, sell 1 unit at price 8960.850000, investment 1.252542 %, total balance 75630.980000,
# day 844, sell 1 unit at price 9021.830000, investment -0.034903 %, total balance 84652.810000,
# day 845, sell 1 unit at price 8947.150000, investment -0.736669 %, total balance 93599.960000,
# day 847: buy 1 unit at price 8971.070000, total balance 84628.890000
# day 848: buy 1 unit at price 8979.730000, total balance 75649.160000
# day 850: buy 1 unit at price 9007.920000, total balance 66641.240000
# day 852, sell 1 unit at price 9018.180000, investment 1.920493 %, total balance 75659.420000,
# day 854: buy 1 unit at price 9082.590000, total balance 66576.830000
# day 856, sell 1 unit at price 9313.000000, investment 5.294339 %, total balance 75889.830000,
# day 857, sell 1 unit at price 9224.980000, investment 3.210208 %, total balance 85114.810000,
# day 858: buy 1 unit at price 9226.810000, total balance 75888.000000
# day 859, sell 1 unit at price 9230.000000, investment 2.886278 %, total balance 85118.000000,
# day 860, sell 1 unit at price 9273.390000, investment 3.270254 %, total balance 94391.390000,
# day 862: buy 1 unit at price 9265.770000, total balance 85125.620000
# day 863: buy 1 unit at price 9234.580000, total balance 75891.040000
# day 864: buy 1 unit at price 9237.730000, total balance 66653.310000
# day 866: buy 1 unit at price 9276.990000, total balance 57376.320000
# day 867: buy 1 unit at price 9357.090000, total balance 48019.230000
# day 868: buy 1 unit at price 9142.920000, total balance 38876.310000
# day 869: buy 1 unit at price 9183.700000, total balance 29692.610000
# day 873: buy 1 unit at price 9276.570000, total balance 20416.040000
# day 874, sell 1 unit at price 9269.000000, investment 2.898338 %, total balance 29685.040000,
# day 875, sell 1 unit at price 9251.830000, investment 1.863345 %, total balance 38936.870000,
# day 878: buy 1 unit at price 9312.990000, total balance 29623.880000
# day 879: buy 1 unit at price 9290.480000, total balance 20333.400000
# day 882, sell 1 unit at price 9486.530000, investment 2.814841 %, total balance 29819.930000,
# day 884: buy 1 unit at price 9515.510000, total balance 20304.420000
# day 885: buy 1 unit at price 9631.030000, total balance 10673.390000
# day 886, sell 1 unit at price 9832.080000, investment 6.111850 %, total balance 20505.470000,
# day 888: buy 1 unit at price 9863.930000, total balance 10641.540000
# day 889: buy 1 unit at price 9797.340000, total balance 844.200000
# day 897, sell 1 unit at price 9907.370000, investment 7.285551 %, total balance 10751.570000,
# day 898: buy 1 unit at price 9866.140000, total balance 885.430000
# day 901, sell 1 unit at price 9859.900000, investment 6.735096 %, total balance 10745.330000,
# day 903, sell 1 unit at price 9953.090000, investment 7.287924 %, total balance 20698.420000,
# day 904: buy 1 unit at price 9899.750000, total balance 10798.670000
# day 905: buy 1 unit at price 9829.120000, total balance 969.550000
# day 917, sell 1 unit at price 9868.790000, investment 5.468581 %, total balance 10838.340000,
# day 920, sell 1 unit at price 9863.020000, investment 7.876040 %, total balance 20701.360000,
# day 921: buy 1 unit at price 9830.230000, total balance 10871.130000
# day 923: buy 1 unit at price 9697.550000, total balance 1173.580000
# day 925, sell 1 unit at price 9677.250000, investment 5.374196 %, total balance 10850.830000,
# day 927, sell 1 unit at price 9628.980000, investment 3.798926 %, total balance 20479.810000,
# day 928, sell 1 unit at price 9638.850000, investment 3.498984 %, total balance 30118.660000,
# day 929: buy 1 unit at price 9670.570000, total balance 20448.090000
# day 930, sell 1 unit at price 9717.990000, investment 4.601592 %, total balance 30166.080000,
# day 932: buy 1 unit at price 9688.620000, total balance 20477.460000
# day 933, sell 1 unit at price 9758.840000, investment 2.557193 %, total balance 30236.300000,
# day 936: buy 1 unit at price 9744.770000, total balance 20491.530000
# day 937, sell 1 unit at price 9655.280000, investment 0.251790 %, total balance 30146.810000,
# day 939: buy 1 unit at price 9600.510000, total balance 20546.300000
# day 940: buy 1 unit at price 9539.400000, total balance 11006.900000
# day 942: buy 1 unit at price 8712.010000, total balance 2294.890000
# day 947, sell 1 unit at price 8602.630000, investment -12.786993 %, total balance 10897.520000,
# day 948, sell 1 unit at price 8812.280000, investment -10.054362 %, total balance 19709.800000,
# day 949, sell 1 unit at price 8811.660000, investment -10.687868 %, total balance 28521.460000,
# day 950, sell 1 unit at price 8749.730000, investment -11.616657 %, total balance 37271.190000,
# day 951, sell 1 unit at price 8810.200000, investment -10.366340 %, total balance 46081.390000,
# day 952: buy 1 unit at price 8737.350000, total balance 37344.040000
# day 957: buy 1 unit at price 8270.000000, total balance 29074.040000
# day 958: buy 1 unit at price 8527.850000, total balance 20546.190000
# day 959, sell 1 unit at price 8487.430000, investment -13.659904 %, total balance 29033.620000,
# day 960: buy 1 unit at price 8502.940000, total balance 20530.680000
# day 961, sell 1 unit at price 8663.940000, investment -10.658465 %, total balance 29194.620000,
# day 962: buy 1 unit at price 8717.940000, total balance 20476.680000
# day 963, sell 1 unit at price 8777.990000, investment -9.229859 %, total balance 29254.670000,
# day 964, sell 1 unit at price 8722.770000, investment -9.968912 %, total balance 37977.440000,
# day 965: buy 1 unit at price 8770.160000, total balance 29207.280000
# day 966, sell 1 unit at price 8713.410000, investment -10.583729 %, total balance 37920.690000,
# day 967, sell 1 unit at price 8748.070000, investment -8.879112 %, total balance 46668.760000,
# day 969, sell 1 unit at price 8634.530000, investment -9.485607 %, total balance 55303.290000,
# day 970, sell 1 unit at price 8689.260000, investment -0.261134 %, total balance 63992.550000,
# day 971: buy 1 unit at price 8684.340000, total balance 55308.210000
# day 973: buy 1 unit at price 8636.070000, total balance 46672.140000
# day 974: buy 1 unit at price 8487.100000, total balance 38185.040000
# day 975, sell 1 unit at price 8803.070000, investment 0.752173 %, total balance 46988.110000,
# day 978, sell 1 unit at price 8846.120000, investment 6.966385 %, total balance 55834.230000,
# day 979, sell 1 unit at price 8871.890000, investment 4.034311 %, total balance 64706.120000,
# day 980, sell 1 unit at price 8882.960000, investment 4.469278 %, total balance 73589.080000,
# day 981: buy 1 unit at price 8604.340000, total balance 64984.740000
# day 982: buy 1 unit at price 8506.760000, total balance 56477.980000
# day 983, sell 1 unit at price 8605.350000, investment -1.291475 %, total balance 65083.330000,
# day 985: buy 1 unit at price 8630.160000, total balance 56453.170000
# day 986, sell 1 unit at price 8589.840000, investment -2.056063 %, total balance 65043.010000,
# day 987: buy 1 unit at price 8601.370000, total balance 56441.640000
# day 988, sell 1 unit at price 8561.520000, investment -1.414270 %, total balance 65003.160000,
# day 990: buy 1 unit at price 8619.500000, total balance 56383.660000
# day 991, sell 1 unit at price 8637.510000, investment 0.016674 %, total balance 65021.170000,
# day 992, sell 1 unit at price 8716.070000, investment 2.697859 %, total balance 73737.240000,
# day 994, sell 1 unit at price 8730.750000, investment 1.469142 %, total balance 82467.990000,
# day 995, sell 1 unit at price 8704.750000, investment 2.327443 %, total balance 91172.740000,
# day 996: buy 1 unit at price 8656.050000, total balance 82516.690000
# day 997, sell 1 unit at price 8749.750000, investment 1.385722 %, total balance 91266.440000,
# ...
# day 8433, sell 1 unit at price 57863.140000, investment -0.248194 %, total balance 272806.000000,
# day 8436: buy 1 unit at price 59250.810000, total balance 213555.190000
# day 8437: buy 1 unit at price 58221.010000, total balance 155334.180000
# day 8438: buy 1 unit at price 57293.790000, total balance 98040.390000
# day 8442: buy 1 unit at price 57648.160000, total balance 40392.230000
# day 8444, sell 1 unit at price 57393.180000, investment -1.723973 %, total balance 97785.410000,
# day 8446: buy 1 unit at price 57779.840000, total balance 40005.570000
# day 8447, sell 1 unit at price 57866.120000, investment -0.523033 %, total balance 97871.690000,
# day 8448: buy 1 unit at price 58364.760000, total balance 39506.930000
# day 8449, sell 1 unit at price 58142.290000, investment 0.156723 %, total balance 97649.220000,
# day 8451, sell 1 unit at price 58338.070000, investment -1.540468 %, total balance 155987.290000,
# day 8452, sell 1 unit at price 58300.000000, investment 0.135673 %, total balance 214287.290000,
# day 8454: buy 1 unit at price 58831.330000, total balance 155455.960000
# day 8455, sell 1 unit at price 58849.990000, investment 2.716176 %, total balance 214305.950000,
# day 8457: buy 1 unit at price 58729.990000, total balance 155575.960000
# day 8459, sell 1 unit at price 58859.790000, investment 2.101767 %, total balance 214435.750000,
# day 8460: buy 1 unit at price 58864.300000, total balance 155571.450000
# day 8461, sell 1 unit at price 58800.000000, investment 1.765599 %, total balance 214371.450000,
# day 8463: buy 1 unit at price 58372.400000, total balance 155999.050000
# day 8464: buy 1 unit at price 58648.780000, total balance 97350.270000
# day 8465: buy 1 unit at price 58501.560000, total balance 38848.710000
# day 8466, sell 1 unit at price 58030.010000, investment -0.573548 %, total balance 96878.720000,
# day 8467, sell 1 unit at price 58639.330000, investment -0.326357 %, total balance 155518.050000,
# day 8470: buy 1 unit at price 58367.740000, total balance 97150.310000
# day 8471: buy 1 unit at price 58209.830000, total balance 38940.480000
# day 8472, sell 1 unit at price 58131.570000, investment -1.018934 %, total balance 97072.050000,
# day 8475, sell 1 unit at price 58671.460000, investment -0.327601 %, total balance 155743.510000,
# day 8477: buy 1 unit at price 58687.970000, total balance 97055.540000
# day 8478, sell 1 unit at price 59242.470000, investment 1.490550 %, total balance 156298.010000,
# day 8480: buy 1 unit at price 59033.130000, total balance 97264.880000
# day 8481: buy 1 unit at price 59365.020000, total balance 37899.860000
# day 8485, sell 1 unit at price 59173.030000, investment 0.893880 %, total balance 97072.890000,
# day 8487: buy 1 unit at price 58519.840000, total balance 38553.050000
# day 8491, sell 1 unit at price 58331.430000, investment -0.290813 %, total balance 96884.480000,
# day 8492, sell 1 unit at price 58180.000000, investment -0.321650 %, total balance 155064.480000,
# day 8494, sell 1 unit at price 57790.000000, investment -0.721236 %, total balance 212854.480000,
# day 8496: buy 1 unit at price 57129.990000, total balance 155724.490000
# day 8498: buy 1 unit at price 56972.680000, total balance 98751.810000
# day 8499, sell 1 unit at price 57161.380000, investment -2.601197 %, total balance 155913.190000,
# day 8500: buy 1 unit at price 55963.320000, total balance 99949.870000
# day 8501, sell 1 unit at price 56134.340000, investment -4.910446 %, total balance 156084.210000,
# day 8504, sell 1 unit at price 57026.800000, investment -3.938717 %, total balance 213111.010000,
# day 8505, sell 1 unit at price 57177.370000, investment -2.294042 %, total balance 270288.380000,
# day 8507, sell 1 unit at price 57222.310000, investment 0.161596 %, total balance 327510.690000,
# day 8508: buy 1 unit at price 57249.140000, total balance 270261.550000
# day 8509, sell 1 unit at price 57365.080000, investment 0.688751 %, total balance 327626.630000,
# day 8511: buy 1 unit at price 57760.480000, total balance 269866.150000
# day 8512, sell 1 unit at price 58087.790000, investment 3.796183 %, total balance 327953.940000,
# day 8514: buy 1 unit at price 57351.560000, total balance 270602.380000
# day 8515, sell 1 unit at price 56590.760000, investment -1.150026 %, total balance 327193.140000,
# day 8516: buy 1 unit at price 56623.190000, total balance 270569.950000
# day 8518, sell 1 unit at price 57563.630000, investment -0.340804 %, total balance 328133.580000,
# day 8519, sell 1 unit at price 57615.800000, investment 0.460737 %, total balance 385749.380000,
# day 8520: buy 1 unit at price 57597.390000, total balance 328151.990000
# day 8521, sell 1 unit at price 57678.120000, investment 1.863071 %, total balance 385830.110000,
# day 8522, sell 1 unit at price 57576.500000, investment -0.036269 %, total balance 443406.610000,
# day 8528: buy 1 unit at price 56969.980000, total balance 386436.630000
# day 8529, sell 1 unit at price 56990.020000, investment 0.035176 %, total balance 443426.650000,
# day 8531: buy 1 unit at price 56753.600000, total balance 386673.050000
# day 8534: buy 1 unit at price 55524.990000, total balance 331148.060000
# day 8535: buy 1 unit at price 54507.620000, total balance 276640.440000
# day 8536: buy 1 unit at price 54566.770000, total balance 222073.670000
# day 8542, sell 1 unit at price 54684.830000, investment -3.645178 %, total balance 276758.500000,
# day 8543, sell 1 unit at price 54438.640000, investment -1.956506 %, total balance 331197.140000,
# day 8544, sell 1 unit at price 53532.250000, investment -1.789420 %, total balance 384729.390000,
# day 8545, sell 1 unit at price 53306.840000, investment -2.308969 %, total balance 438036.230000,
# day 8554: buy 1 unit at price 55165.190000, total balance 382871.040000
# day 8555: buy 1 unit at price 55548.520000, total balance 327322.520000
# day 8556, sell 1 unit at price 55710.870000, investment 0.989175 %, total balance 383033.390000,
# day 8557, sell 1 unit at price 55364.690000, investment -0.330936 %, total balance 438398.080000,
# day 8558: buy 1 unit at price 55008.460000, total balance 383389.620000
# day 8559: buy 1 unit at price 54452.600000, total balance 328937.020000
# day 8560: buy 1 unit at price 54646.590000, total balance 274290.430000
# day 8562: buy 1 unit at price 54340.890000, total balance 219949.540000
# day 8563, sell 1 unit at price 53688.070000, investment -2.400340 %, total balance 273637.610000,
# day 8564, sell 1 unit at price 54466.360000, investment 0.025270 %, total balance 328103.970000,
# day 8566, sell 1 unit at price 54350.540000, investment -0.541754 %, total balance 382454.510000,
# day 8567, sell 1 unit at price 54122.070000, investment -0.402680 %, total balance 436576.580000,
# day 8568: buy 1 unit at price 54100.000000, total balance 382476.580000
# day 8569: buy 1 unit at price 54662.790000, total balance 327813.790000
# day 8572, sell 1 unit at price 56404.730000, investment 4.260129 %, total balance 384218.520000,
# day 8573, sell 1 unit at price 56465.750000, investment 3.298331 %, total balance 440684.270000,
# day 8577: buy 1 unit at price 56539.350000, total balance 384144.920000
# day 8578: buy 1 unit at price 56298.120000, total balance 327846.800000
# day 8582: buy 1 unit at price 54736.530000, total balance 273110.270000
# day 8583: buy 1 unit at price 54058.850000, total balance 219051.420000
# day 8584: buy 1 unit at price 53749.990000, total balance 165301.430000
# day 8586: buy 1 unit at price 52303.650000, total balance 112997.780000
# day 8587, sell 1 unit at price 52626.910000, investment -6.919853 %, total balance 165624.690000,
# day 8588, sell 1 unit at price 51830.210000, investment -7.936162 %, total balance 217454.900000,
# day 8589, sell 1 unit at price 52255.370000, investment -4.532914 %, total balance 269710.270000,
# day 8590, sell 1 unit at price 52122.860000, investment -3.581264 %, total balance 321833.130000,
# day 8591, sell 1 unit at price 52250.970000, investment -2.788875 %, total balance 374084.100000,
# day 8593: buy 1 unit at price 52975.460000, total balance 321108.640000
# day 8595, sell 1 unit at price 52611.360000, investment 0.588315 %, total balance 373720.000000,
# day 8599: buy 1 unit at price 51076.920000, total balance 322643.080000
# day 8600: buy 1 unit at price 51653.760000, total balance 270989.320000
# day 8603, sell 1 unit at price 51306.950000, investment -3.149590 %, total balance 322296.270000,
# day 8604: buy 1 unit at price 51620.600000, total balance 270675.670000
# day 8605, sell 1 unit at price 52236.720000, investment 2.270693 %, total balance 322912.390000,
# day 8606, sell 1 unit at price 52195.190000, investment 1.048191 %, total balance 375107.580000,
# day 8607, sell 1 unit at price 51980.750000, investment 0.697687 %, total balance 427088.330000,
# day 8609: buy 1 unit at price 51741.600000, total balance 375346.730000
# day 8610, sell 1 unit at price 51293.780000, investment -0.865493 %, total balance 426640.510000,
# day 8615: buy 1 unit at price 52693.130000, total balance 373947.380000
# day 8616, sell 1 unit at price 52825.670000, investment 0.251532 %, total balance 426773.050000,
# day 8618: buy 1 unit at price 53569.850000, total balance 373203.200000
# day 8619, sell 1 unit at price 53365.170000, investment -0.382081 %, total balance 426568.370000,
# day 8620: buy 1 unit at price 53331.620000, total balance 373236.750000
# day 8622: buy 1 unit at price 52710.960000, total balance 320525.790000
# day 8623, sell 1 unit at price 53001.570000, investment -0.618864 %, total balance 373527.360000,
# day 8626: buy 1 unit at price 53308.270000, total balance 320219.090000
# day 8627, sell 1 unit at price 53776.050000, investment 2.020623 %, total balance 373995.140000,
# day 8628, sell 1 unit at price 53823.980000, investment 0.967411 %, total balance 427819.120000,
# day 8630: buy 1 unit at price 53778.550000, total balance 374040.570000
# day 8631, sell 1 unit at price 53960.000000, investment 0.337402 %, total balance 428000.570000,
# day 8634: buy 1 unit at price 55025.590000, total balance 372974.980000
# day 8635, sell 1 unit at price 54745.380000, investment -0.509236 %, total balance 427720.360000,
# day 8637: buy 1 unit at price 54745.000000, total balance 372975.360000
# day 8638: buy 1 unit at price 54760.970000, total balance 318214.390000
# day 8641: buy 1 unit at price 55027.160000, total balance 263187.230000
# day 8642, sell 1 unit at price 54950.280000, investment 0.374975 %, total balance 318137.510000,
# day 8643: buy 1 unit at price 54925.060000, total balance 263212.450000
# day 8644: buy 1 unit at price 55013.420000, total balance 208199.030000
# day 8645, sell 1 unit at price 54680.000000, investment -0.147861 %, total balance 262879.030000,
# day 8647: buy 1 unit at price 54291.280000, total balance 208587.750000
# day 8650: buy 1 unit at price 54961.850000, total balance 153625.900000
# day 8651, sell 1 unit at price 56167.460000, investment 2.072249 %, total balance 209793.360000,
# day 8654: buy 1 unit at price 55765.010000, total balance 154028.350000
# day 8657: buy 1 unit at price 56370.940000, total balance 97657.410000
# day 8658: buy 1 unit at price 55817.140000, total balance 41840.270000
# day 8659, sell 1 unit at price 56020.280000, investment 1.994026 %, total balance 97860.550000,
# day 8663: buy 1 unit at price 56272.490000, total balance 41588.060000
# day 8664, sell 1 unit at price 56269.490000, investment 2.283207 %, total balance 97857.550000,
# day 8666: buy 1 unit at price 56200.660000, total balance 41656.890000
# day 8667, sell 1 unit at price 56296.570000, investment 3.693577 %, total balance 97953.460000,
# day 8669: buy 1 unit at price 56085.930000, total balance 41867.530000
# day 8670, sell 1 unit at price 55787.030000, investment 1.501369 %, total balance 97654.560000,
# day 8671, sell 1 unit at price 55525.240000, investment -0.429965 %, total balance 153179.800000,
# day 8674: buy 1 unit at price 56354.350000, total balance 96825.450000
# day 8675, sell 1 unit at price 56275.590000, investment -0.169147 %, total balance 153101.040000,
# day 8677: buy 1 unit at price 55192.080000, total balance 97908.960000
# day 8678: buy 1 unit at price 55208.690000, total balance 42700.270000
# day 8682, sell 1 unit at price 55777.630000, investment -0.070785 %, total balance 98477.900000,
# day 8683, sell 1 unit at price 55409.670000, investment -1.533289 %, total balance 153887.570000,
# day 8684: buy 1 unit at price 55241.280000, total balance 98646.290000
# day 8685: buy 1 unit at price 55349.990000, total balance 43296.300000
# day 8686, sell 1 unit at price 55371.600000, investment -1.475178 %, total balance 98667.900000,
# day 8687, sell 1 unit at price 55315.010000, investment -1.374534 %, total balance 153982.910000,
# day 8689, sell 1 unit at price 55401.260000, investment -1.691245 %, total balance 209384.170000,
# day 8692, sell 1 unit at price 57922.200000, investment 4.946579 %, total balance 267306.370000,
# day 8693, sell 1 unit at price 58024.510000, investment 5.100320 %, total balance 325330.880000,
# day 8694, sell 1 unit at price 57854.320000, investment 4.730231 %, total balance 383185.200000,
# day 8695: buy 1 unit at price 58035.180000, total balance 325150.020000
# day 8698: buy 1 unit at price 57719.740000, total balance 267430.280000
# day 8699: buy 1 unit at price 57624.770000, total balance 209805.510000
# day 8703: buy 1 unit at price 57277.130000, total balance 152528.380000
# day 8704: buy 1 unit at price 57547.600000, total balance 94980.780000
# day 8705, sell 1 unit at price 57747.010000, investment 4.330660 %, total balance 152727.790000,
# day 8706, sell 1 unit at price 57635.470000, investment -0.688737 %, total balance 210363.260000,
# day 8707: buy 1 unit at price 57520.410000, total balance 152842.850000
# day 8708, sell 1 unit at price 57439.670000, investment -0.485224 %, total balance 210282.520000,
# day 8712, sell 1 unit at price 57670.130000, investment 0.078716 %, total balance 267952.650000,
# day 8714: buy 1 unit at price 58116.170000, total balance 209836.480000
# day 8715: buy 1 unit at price 57940.000000, total balance 151896.480000
# day 8716, sell 1 unit at price 58873.910000, investment 2.787814 %, total balance 210770.390000,
# day 8720: buy 1 unit at price 58890.010000, total balance 151880.380000
# day 8722: buy 1 unit at price 58526.420000, total balance 93353.960000
# day 8723: buy 1 unit at price 58698.260000, total balance 34655.700000
# day 8724, sell 1 unit at price 58700.000000, investment 2.002516 %, total balance 93355.700000,
# day 8726: buy 1 unit at price 59060.000000, total balance 34295.700000
# day 8727, sell 1 unit at price 58627.000000, investment 1.923821 %, total balance 92922.700000,
# day 8728: buy 1 unit at price 58722.880000, total balance 34199.820000
# day 8729, sell 1 unit at price 58682.410000, investment 0.974324 %, total balance 92882.230000,
# day 8730: buy 1 unit at price 58746.570000, total balance 34135.660000
# day 8731, sell 1 unit at price 58991.520000, investment 1.814843 %, total balance 93127.180000,
# day 8734: buy 1 unit at price 58608.630000, total balance 34518.550000
# day 8736, sell 1 unit at price 58710.950000, investment -0.304058 %, total balance 93229.500000,
# day 8738: buy 1 unit at price 58173.830000, total balance 35055.670000
# day 8745, sell 1 unit at price 58588.160000, investment 0.105491 %, total balance 93643.830000,
# day 8747, sell 1 unit at price 59000.000000, investment 0.514053 %, total balance 152643.830000,
# day 8748, sell 1 unit at price 59251.990000, investment 0.325076 %, total balance 211895.820000,
# day 8749: buy 1 unit at price 59299.450000, total balance 152596.370000
# day 8750, sell 1 unit at price 58553.120000, investment -0.289087 %, total balance 211149.490000,
# day 8754: buy 1 unit at price 58740.550000, total balance 152408.940000
# day 8755: buy 1 unit at price 59221.950000, total balance 93186.990000
# day 8756, sell 1 unit at price 59143.720000, investment 0.676039 %, total balance 152330.710000,
# day 8757: buy 1 unit at price 59086.990000, total balance 93243.720000
# day 8758: buy 1 unit at price 59119.020000, total balance 34124.700000
